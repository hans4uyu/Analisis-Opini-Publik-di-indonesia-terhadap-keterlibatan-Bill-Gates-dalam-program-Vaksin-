# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("Data_BillGates_vaksin_Final_2025.csv")

# %%
df
# Out:
#                                               full_text  \
# 0     world health organization inilah sumber bencan...
# 1     bill gates seorang filantropis dermawan big   ...
# 2     jangan percaya sama orang selama akhir zaman d...
# 3     nyata tidak   akui pemerintah   negara tingkat...
# 4     biang kerok pandemi vaksin dia setuju soal kec...
# ...                                                 ...
# 998   kamar kuramata isa akiko taku memiliki suara s...
# 999   kembiskes bangga gelar forum bersama bill gate...
# 1000  aku takut ketapel ajaib namboru sedang antri v...
# 1001  assalamu alaikum dokter isunya mulai sakit abi...
# 1002  dokter kathryn terhormat ada kemungkinan walau...
#
#                           created_at
# 0     Thu Feb 27 09:02:18 +0000 2025
# 1     Wed Feb 26 01:22:01 +0000 2025
# 2     Sun Feb 23 07:22:17 +0000 2025
# 3     Sun Feb 23 00:15:50 +0000 2025
# 4     Thu Feb 20 15:12:34 +0000 2025
# ...                              ...
# ...

# %%
vectorizer = TfidfVectorizer(
    lowercase=True,
    stop_words=None,
    ngram_range=(1, 2),
    max_features=5000
)

tfidf_matrix = vectorizer.fit_transform(df["full_text"])
tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=vectorizer.get_feature_names_out()
)

tfidf_df.to_csv("TFIDF_BillGates_vaksin_2025.csv", index=False)

# %%
import numpy as np

tfidf_sum = np.sum(tfidf_matrix.toarray(), axis=0)
top_idx = np.argsort(tfidf_sum)[::-1][:30]
for i in top_idx:
    print(vectorizer.get_feature_names_out()[i], tfidf_sum[i])
# Out:
# vaksin 52.96476945843201
# gates 48.613752487288686
# bill 48.04318927530193
# bill gates 47.80077915418592
# tuberkulosis 40.69293247575515
# vaksin tuberkulosis 37.03450128233429
# indonesia 26.830934469324262
# pengujian 26.813751610080686
# vaksin bill 25.778612677186437
# tuberkulosis bill 25.578644104429245
# coba 23.58866264012428
# pengujian coba 21.54986554798826
# coba vaksin 19.381994031849995
# rakyat 18.584735131217172
# jadi 18.498382644366334
# covid 15.186944512898444
# percobaan 14.696167284890551
# kesehatan 14.291526543770914
# nya 13.906475188524128
# kalau 13.12858561333599
# buat 12.80261100785011
# orang 12.676821392877452
# kelinci 11.972771276714687
# sama 11.927841572346868
# kelinci percobaan 11.31963303360373
# negara 11.164526233834417
# menteri 10.784352554572607
# apa 10.394971436576329
# ada 10.166945438025916
# bukan 9.652343362904418
